# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mu,sigma=5,1
x = np.random.normal(mu,sigma,10)
x
# Out:
# array([4.8739673 , 6.23797574, 4.87653007, 3.56348825, 3.95530553,
#        6.40833842, 4.7960244 , 3.91153417, 6.8494312 , 5.45326239])

# %%
np.mean(x)
# Out:
# 5.092585747257349

# %%
y = 1/(np.sqrt(2*np.pi*sigma**2)) * np.exp(-0.5*((x-mu)/sigma)**2)
y
# Out:
# array([0.39578638, 0.18540169, 0.39591294, 0.14217145, 0.23116309,
#        0.1479846 , 0.3907288 , 0.22061913, 0.07214074, 0.35999615])

# %%
sns.lineplot(x,y,color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("guassian.png")

# %%
spc=np.linspace(1,10,12)
spc
# Out:
# array([ 1.        ,  1.81818182,  2.63636364,  3.45454545,  4.27272727,
#         5.09090909,  5.90909091,  6.72727273,  7.54545455,  8.36363636,
#         9.18181818, 10.        ])

# %%
def liklihood(z):
    ans= 1/(np.sqrt(2*np.pi*sigma**2)) * np.exp(-0.5*((x-z)/sigma)**2)
    return ans

# %%
plt.figure(figsize = (20,15))
for i in range(1,12,1):
    y1=liklihood(space[i])
    plt.subplot(3,4,i)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('mean='+str(round(spc[i],6))+', variance='+str(round(spc[i],6)),color='red')
    sns.lineplot(x,y1,color='blue')
    plt.savefig("MLE.png")
